# %% [markdown]
# # What is feature scaling

# %% [markdown]
# Feature scaling is a technique to standardize the independent features present in the data in a fixed range

# %% [markdown]
# # Why do we need feature scaling

# %% [markdown]
# Let x be the no. of Salary and y be the no. of Age<br>
# Example: x1 & y1 are in row 2, x2 & y2 are in row 9<br>
# (X2-X1)^2 = (83000-48000)^2<br>
# =1225000000<br>
# (y2-y1)^2=(50-27)^2<br>
# =529<br>

# %% [markdown]
# # Types of feature scaling

# %% [markdown]
# There are basically two types of feature scaling<br>
# 1> Standardization<br>
# 2> Normalization<br>
# a>min max scaler<br>
# b>robust scaler<br>

# %% [markdown]
# # <font color='green'>Standardization</font>

# %% [markdown]
# Standardization is also called as z-score Normalization

# %% [markdown]
# ![WhatsApp%20Image%202023-09-30%20at%2018.57.09_7cd82f11.jpg](attachment:WhatsApp%20Image%202023-09-30%20at%2018.57.09_7cd82f11.jpg)

# %% [markdown]
# Mean Centering :<br>
# If we plot graph of new age' and salary' the mean will become = 0 and will locate at origin . This shifting of mean from any position to origi is called mean centering.

# %% [markdown]
# SD:
# The spread of the (range) of the values will also decrease from originally it was . consider SD originally was 5 and it will decrease to say 1.

# %% [markdown]
# ![WhatsApp%20Image%202023-09-30%20at%2019.05.59_b7d67020.jpg](attachment:WhatsApp%20Image%202023-09-30%20at%2019.05.59_b7d67020.jpg)

# %% [markdown]
# # Impact of outlier

# %% [markdown]
# Outlier acts as outlier only after standardization . It is not affected by SD factor and does not getted near center

# %% [markdown]
# ![eff_out.png](attachment:eff_out.png)

# %% [markdown]
# # When to use Standardization

# %% [markdown]
# When we are using any of the below algo then we need to use standardization

# %% [markdown]
# ![1_qRmiffZgkNaXnTBZwDafCA.png](attachment:1_qRmiffZgkNaXnTBZwDafCA.png)
