# %% [markdown]
# # <font color ='orange'>Feature Engineering</font>

# %% [markdown]
# ## Feature engineering is the process of using domain knowledge to extract features from raw data . These features can be used to improve the performance of machine learning algorithm .

# %% [markdown]
# ## Feature Engineering consists of :
#     Step 1 :Feature Transformation
#                  Missing Value Imputation
#                  Handling Categorical Features
#                  Outlier Detection
#                  Feature Scaling

# %% [markdown]
# Step 2: Feature Construction <br>
#           &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sometimes features required by us are not readly available in data/dataset,we need to add the features manually this             process or this term is know as &nbsp;&nbsp;&nbsp;feature construction.

# %% [markdown]
# Step 3: Feature Selection

# %% [markdown]
# Step 4: Feature Extraction
# Generating completely new features from existing features with the help of programs

# %% [markdown]
# # <font color='brown'>Feature Transformation</font>

# %% [markdown]
# ## <font color='green'>Missing value Imputation</font>

# %% [markdown]
# It is very imp to deal with missing values before passing to model as sklearn deos not consider the missing values we can either fill those values or we have to remove those values

# %% [markdown]
# ## <font color='green'>Handling Categorical Data</font>

# %% [markdown]
# If we have feature / column containing categorical values or data then again there is problem that sklearn only deals with numberical data then we need to convert categorical data into numberical form.
# consider eg we have feature 'animal' containing few animal names and we have to convert into numberical form

# %% [markdown]
# ![Screenshot-from-2020-08-12-17-16-03.jpg](attachment:Screenshot-from-2020-08-12-17-16-03.jpg)

# %% [markdown]
# ## <font color='green'>Outliers detection</font>

# %% [markdown]
# A value which varies on a large extent from data  which decreases accuracy<br>
# in below image red points represent outliers. After removing outliers line of linear regression varies

# %% [markdown]
# ![outliers.png](attachment:outliers.png)

# %% [markdown]
# ## <font color='green'>Feature scaling</font>

# %% [markdown]
# If we have features for ex age salary where age is very small in terms of numbers where as salary is very large in numbers. So salary we dominant , it is required to scale the feature before passing to model training. There are various types of scaling

# %% [markdown]
# # <font color='brown'>Feature Construction</font>

# %% [markdown]
# Here we create a new feature from the received data or dataset

# %% [markdown]
# # <font color='brown'>Feature Selection</font>

# %% [markdown]
# As the name suggests here we select the required features only from the data or dataset

# %% [markdown]
# # <font color='brown'>Feature Extraction</font>

# %% [markdown]
# creating completely new features from existing features of dataset using program
